# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Game Move Position
# -|-|-       0|1|2
# -|-|-  ---> 3|4|5
# -|-|-       6|7|8

# %%
# Data
results = ['Losses', 'Draws', 'Wins']
values = [8, 2, 0]

# Colors for each section
colors = ['red', 'yellow', 'green']

# Plotting the pie chart
plt.pie(values, labels=results, colors=colors, autopct='%1.1f%%', startangle=140)

# Title of the pie chart
plt.title('Match Result')

# Display the pie chart
plt.show()

# %%
# Data
results = ['Losses', 'Draws', 'Wins']
values = [3, 6, 1]

# Colors for each section
colors = ['blue', 'green', 'brown']

# Plotting the pie chart
plt.pie(values, labels=results, colors=colors, autopct='%1.1f%%', startangle=140)

# Title of the pie chart
plt.title('Match Result')

# Display the pie chart
plt.show()

# %%
# Data
results = ['Losses', 'Draws', 'Wins']
values = [2, 8, 0]

# Colors for each section
colors = ['orange', '#D2B48C', 'yellow']

# Plotting the pie chart
plt.pie(values, labels=results, colors=colors, autopct='%1.1f%%', startangle=140)

# Title of the pie chart
plt.title('Match Result')

# Display the pie chart
plt.show()

# %%
# Data
results = ['Losses', 'Draws', 'Wins']
values = [2, 3, 5]

# Colors for each section
colors = ['red', 'yellow', 'green']

# Plotting the pie chart
plt.pie(values, labels=results, colors=colors, autopct='%1.1f%%', startangle=140)

# Title of the pie chart
plt.title('Match Result')

# Display the pie chart
plt.show()
